# %%
# pip install pycaret

# %%
# https://towardsdatascience.com/build-and-deploy-your-first-machine-learning-web-app-e020db344a99

# %%
# imports
import pandas as pd
from pycaret.regression import *

# %%
data = pd.read_csv("data/insurance.csv")

# %%
# Experiment No. 2
from pycaret.regression import *
r2 = setup(data, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True, trigonometry_features = True,
           feature_interaction=True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row15_col1 {
#             background-color:  lightgreen;
#         }    #T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row25_col1 {
#             background-color:  lightgreen;
#         }    #T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row32_col1 {
#             background-color:  lightgreen;
#         }    #T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row34_col1 {
#             background-color:  lightgreen;
#         }    #T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row39_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row3_col1" class="data row3 col1" >(1338, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row10_col1" class="data row10 col1" >(1338, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row11_col1" class="data row11 col1" >(936, 62)</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row12_col1" class="data row12 col1" >(402, 62)</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_dfb83052_8bcd_11ea_b9e9_c4346b433bf4row17_col0" class="data row17 col0" >Transformation </td>

# %%
# Model Training and Validation 
lr = create_model('lr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     3002.5846  2.077240e+07  4557.6744  0.8759  0.4128  0.3475
# 1     3591.8251  3.312183e+07  5755.1566  0.8074  0.4594  0.3510
# 2     3072.2905  2.396757e+07  4895.6689  0.6965  0.5546  0.4000
# 3     3259.9188  2.735765e+07  5230.4540  0.7716  0.5585  0.4885
# 4     3312.7824  2.896222e+07  5381.6563  0.7846  0.4704  0.3068
# 5     3196.3410  2.438534e+07  4938.1514  0.8431  0.3681  0.2817
# 6     2957.0005  2.617558e+07  5116.2073  0.8219  0.3929  0.3182
# 7     3503.4771  3.046852e+07  5519.8298  0.8325  0.5738  0.3125
# 8     3179.3624  2.289010e+07  4784.3594  0.8522  0.4057  0.3494
# 9     3277.7729  2.905955e+07  5390.6913  0.8128  0.5153  0.3698
# Mean  3235.3355  2.671608e+07  5156.9850  0.8099  0.4712  0.3525
# SD     192.4236  3.595934e+06   348.6860  0.0478  0.0719  0.0556

# %%
# plot residuals of trained model
plot_model(lr, plot = 'residuals')

# %%
# save transformation pipeline and model 
save_model(lr, model_name = 'models/deployment_05012020')
# Out:
# Transformation Pipeline and Model Succesfully Saved
